# %% [markdown]
# <a href="https://colab.research.google.com/github/Premkumarbajaru/Stream-LLM-Responses-in-Groq/blob/master/Stream_LLM_Responses.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain-community langchain langchain-groq -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 56.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.4/127.4 kB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.2 MB/s eta 0:00:00

# %%
import os
from langchain_groq import ChatGroq

# %%
os.environ["GROQ_API_KEY"] = "enter groq api key"

# %%
llm = ChatGroq(
    model ="llama-3.1-8b-instant",
    temperature = 0
)

# %%
response = llm.invoke("Write me a song about sunrise in 2000words")
print(response.content)
# Out:
# **Verse 1**
# (Soft, gentle melody)
# In the still of the night, when darkness reigns
# The world is hushed, in a peaceful refrain
# The stars up above, a twinkling show
# A celestial map, guiding us to the dawn below
#
# The moon, a glowing crescent, casts a silver light
# On the horizon, where the day will take flight
# The shadows stretch, and the world awakens slow
# As the first hints of dawn, begin to unfold
#
# **Chorus**
# (Soaring, uplifting melody)
# Oh, sunrise, you bring us light
# A new beginning, a fresh sight
# The world awakens, and all is made new
# In your radiant glow, our hearts renew
#
# **Verse 2**
# (Gentle, lilting rhythm)
# The sky is painted, with hues of pink and gold
# As the sun rises, the world is told
# To leave its slumber, and greet the day
# With a sense of wonder, and a heart full of play
#
# The clouds are set aflame, with colors bright and bold
# As the sun's rays dance, and the world is made to unfold
# ...

# %% [markdown]
# ### optimizied token by token

# %%
for chunk in llm.stream("Write me a song about sunrise in 2000words"):
  print(chunk.content, end="", flush=True)
# Out:
# **Verse 1**
# (Soft, gentle melody)
# In the still of the night, when darkness reigns
# The world is hushed, in a peaceful refrain
# The stars up above, a twinkling show
# A celestial map, guiding us to the dawn below
#
# The moon, a glowing crescent, casts a silver light
# On the horizon, where shadows take flight
# The wind whispers secrets, of a new day's birth
# As the earth awakens, from its slumber on this earth
#
# **Chorus**
# (Soaring, uplifting melody)
# Oh, sunrise, you bring us light
# A new beginning, a fresh sight
# The world awakens, from its sleep
# As you rise, our hearts start to leap
#
# **Verse 2**
# (Soft, gentle melody)
# The sky is painted, with hues of pink and gold
# A masterpiece, of colors yet untold
# The clouds, a soft and fluffy white
# A gentle caress, on this morning's delight
#
# The sun, a burning fire, begins to rise
# A ball of light, that opens our eyes
# To a world of wonder, of beauty and might
# A new day dawns, and all is made right
#
# ...
